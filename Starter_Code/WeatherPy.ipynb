# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import citipy to determine the nearest city based on latitude and longitude

# Import the OpenWeatherMap API key from config.py
from config import weather_api_key # type: ignore
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 12
#       7 from scipy.stats import linregress
#       9 # Import citipy to determine the nearest city based on latitude and longitude
#      10
#      11 # Import the OpenWeatherMap API key from config.py
# ---> 12 from config import weather_api_key
#
# ModuleNotFoundError: No module named 'config'

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key from config.py
from api_keys import api_key # type: ignore

# Import citipy to determine the cities based on latitude and longitude
from cities import cities # type: ignore
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 10
#       7 from scipy.stats import linregress
#       9 # Import the OpenWeatherMap API key from config.py
# ---> 10 from api_keys import api_key # type: ignore
#      12 # Import citipy to determine the cities based on latitude and longitude
#      13 from cities import cities
#
# ModuleNotFoundError: No module named 'api_keys'

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from flask import app

# Import the OpenWeatherMap API key from config.py
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 11
#       8 from flask import app
#      10 # Import the OpenWeatherMap API key from config.py
# ---> 11 from api_keys import weather_api_key
#      13 # Import citipy to determine the cities based on latitude and longitude
#      14 from citipy import citipy
#
# ModuleNotFoundError: No module named 'api_keys'

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from citipy import citipy

# Import the OpenWeatherMap API key from the api_keys.py module
# Ensure that api_keys.py is in the same directory as this script and contains the variable `weather_api_key`
try:
    from api_keys import weather_api_key
except ModuleNotFoundError:
    print("Error: The 'api_keys' module is not found. Please ensure that 'api_keys.py' exists in the same directory.")

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 8
#       6 import time
#       7 from scipy.stats import linregress
# ----> 8 from citipy import citipy
#      10 # Import the OpenWeatherMap API key from the api_keys.py module
#      11 # Ensure that api_keys.py is in the same directory as this script and contains the variable `weather_api_key`
#      12 try:
#
# ModuleNotFoundError: No module named 'citipy'

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from config import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 10
#       7 from scipy.stats import linregress
#       9 # Import the OpenWeatherMap API key
# ---> 10 from api_keys import weather_api_key
#      12 # Import citipy to determine the cities based on latitude and longitude
#      13 from citipy import citipy
#
# ModuleNotFoundError: No module named 'api_keys'

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 577

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
import requests

# Function to get weather data
def get_weather_data(city, api_key):
    base_url = "http://api.openweathermap.org/data/2.5/weather"
    url = f"{base_url}?q={city}&appid={weather_api_key}&units=metric"
    
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an HTTPError for bad responses (4xx and 5xx)
        data = response.json()
        
        # Check if the API key is invalid
        if data.get("cod") == 401:
            raise ValueError("Invalid API key. Please check your API key and try again.")
        
        return data
    
    except requests.exceptions.HTTPError as http_err:
        print(f"HTTP error occurred: {http_err}")
    except ValueError as val_err:
        print(val_err)
    except Exception as err:
        print(f"An error occurred: {err}")

# Example usage
weather_api_key = "weather_api_key"
cities = [""]

for city in cities:
    data = get_weather_data(city, weather_api_key)
    if data:
        print(data)
# Out:
# HTTP error occurred: 401 Client Error: Unauthorized for url: http://api.openweathermap.org/data/2.5/weather?q=&appid=weather_api_key&units=metric

# %%
# Show Record Count
city_data_df.count()
city_data_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Convert the cities weather data into a Pandas DataFrame

from matplotlib import pyplot as plt

#dcity_data_df = pd [DataFrame]
# Convert to DataFrame
city_data_df = pd.DataFrame(city_data)

# Display the DataFrame
print(city_data_df)

# Show Record Count
city_data_df.count()
city_data_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Display sample data
city_data_df.head()
city_data_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Export the City_Data into a csv
#pd.DataFrame(city_data)

city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
print(city_data_df.head())
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Latitude vs. Temperature

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
plt.scatter(df['Latitude'], df['Temperature'], c='green', edgecolors='w', linewidth=0.5)
plt.title('Latitude vs. Temperature (2024-7-7)')
plt.xlabel('Latitude')
plt.ylabel('Temperature')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
# Incorporate the other graph properties
# YOUR CODE HERE


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Latitude vs. Humidity

from matplotlib import pyplot as plt

plt.figure(figsize=(10, 8))
plt.subplot(2, 2, 2)
plt.scatter(df['Latitude'], df['Humidity'], c='green', edgecolors='w', linewidth=0.5)
plt.title('City Latitude vs. Humidity (2024-7-7)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# Adjust layout and show plots
plt.tight_layout()
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Latitude vs. Cloudiness

from matplotlib import pyplot as plt

plt.figure(figsize=(10, 8))
plt.subplot(2, 2, 3)
plt.scatter(city_data_df['Latitude'], city_data_df['Cloudiness'], c='green', edgecolors='w', linewidth=0.5)
plt.title('Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.tight_layout()
plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Latitude vs. Wind Speed

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 4)
plt.scatter(df['Latitude'], df['Wind Speed'], c='green', edgecolors='w', linewidth=0.5)
plt.title('City Latitude vs. Wind Speed (2024-7-7)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (%)')

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
# Latitude vs. Wind Speed

plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 4)
plt.scatter(df['Latitude'], df['Wind Speed'], c='green', edgecolors='w', linewidth=0.5)
plt.title('City Latitude vs. Wind Speed (2024-7-7)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (%)')


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")
city_data_df
# Out:
#          Latitude  Temperature  Humidity  Cloudiness  Wind Speed
# City_ID
# 0         41.6911        25.98        50           0        4.12
# 1        -49.3500         4.13        89          99       13.68
# 2         21.9789        27.24        71          40        8.75
# 3         64.8569        17.14        79          75        1.54
# 4        -25.0660        21.97        90          99       13.17
# ...           ...          ...       ...         ...         ...
# 592        2.7858        21.35        99          98        0.74
# 593       49.4212        17.53        69          49        0.16
# 594       28.3667        27.91        83          98        7.20
# 595      -21.3585        19.77        88          49        6.36
# 596        3.2607        27.98        82          67        1.89
#
# [597 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Read the city data from the CSV file
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")


# Assuming the correct column name is 'Max Temperature' instead of 'Max Temp'
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemisphere_df = city_data_df[city_data_df['Latitude'] >= 0]

# Extract Latitude and Max Temperature for the Northern Hemisphere
latitude = northern_hemisphere_df['Latitude']

# Try to access 'Max Temp' and handle the potential error

max_temp = northern_hemisphere_df['Temperature']

print("Column 'Max Temperature' not found. Trying 'Temperature' instead.")

max_temprature = northern_hemisphere_df['Temperature']

# Calculate linear regression
slope, intercept, r_value, p_value, std_err = linregress(latitude, max_temp)

# Create regression line values
regress_values = latitude * slope + intercept

# Plot scatter plot and regression line
plt.figure(figsize=(10, 8))

# Latitude vs. Temperature
plt.scatter(latitude, max_temp, c='green', edgecolors='w', linewidth=0.5, label='5, 0.5 0.1 ')
plt.plot(latitude, regress_values, 'r-', label=f'Fit line (R²={r_value**2:.2f})')
plt.title('Latitude vs. Temperature (Northern Hemisphere)')
plt.xlabel('Latitude')
plt.ylabel('Max Temp (°C)')
plt.legend()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
# Out:
# Column 'Max Temperature' not found. Trying 'Temperature' instead.

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
northern_hemi_df.head()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Read the city data from the CSV file
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Assuming the correct column name is 'Temperature' instead of 'Max Temp'
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
southern_hemisphere_df = city_data_df[city_data_df['Latitude'] >= 0]

# Extract Latitude and Max Temperature for the Northern Hemisphere
latitude = southern_hemisphere_df['Latitude']

# Try to access 'Max Temp' and handle the potential error

temperature = southern_hemisphere_df['Temperature']

print("Column 'Max Temperature' not found. Trying 'Temperature' instead.")

# Calculate linear regression
slope, intercept, r_value, p_value, std_err = linregress(latitude, temperature)

# Create regression line values
regress_values = latitude * slope + intercept

# Plot scatter plot and regression line
plt.figure(figsize=(10, 8))

# Latitude vs. Temperature
plt.scatter(latitude, temperature, c='green', edgecolors='w', linewidth=0.5, label='5, 0.5 0.1 ')
plt.plot(latitude, regress_values, 'r-', label=f'Fit line (R²={r_value**2:.2f})')
plt.title('Latitude vs. Temperature (Southern Hemisphere)')
plt.xlabel('Latitude')
plt.ylabel('Temperature (°C)')
plt.legend()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()
# Out:
# Column 'Max Temperature' not found. Trying 'Temperature' instead.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Read the city data from the CSV file
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Assuming the correct column name is 'Temperature' instead of 'Max Temp'
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
southern_hemisphere_df = city_data_df[city_data_df['Latitude'] >= 0]

# Extract Latitude and Max Temperature for the Northern Hemisphere
latitude = southern_hemisphere_df['Latitude']

# Try to access 'Max Temp' and handle the potential erro
temperature = southern_hemisphere_df['Temperature']
    
 # Calculate linear regression
slope, intercept, r_value, p_value, std_err = linregress(latitude, temperature)
    
#Create regression line values
regress_values = latitude * slope + intercept
    
# Plot scatter plot and regression line
plt.figure(figsize=(10, 10))
plt.scatter(latitude, temperature, c='green', edgecolors='w', linewidth=0.5, label='5, 0.5 0.1')
plt.plot(latitude, regress_values, 'r-', label=f'Fit line (R²={r_value**2:.2f})')
plt.title(f'Latitude Vrs Temprature Southern Hemisphere)')
plt.xlabel("Latitude")
plt.ylabel('Temperature (°C)')

plt.legend() 

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              kerikeri -35.2268  173.9474     14.39        90         100
# 2        margaret river -33.9500  115.0667     15.44        67          60
# 5              waitangi -43.9535 -176.5597     12.68        98         100
# 7          port lincoln -34.7333  135.8667     13.27        67         100
# 9                 leava -14.3000 -178.1667     28.10        85           8
#
#          Wind Speed Country        Date
# City_ID
# 0              0.98      NZ  1718607765
# 2              3.76      AU  1718607768
# 5              3.13      NZ  1718607771
# 7              3.38      AU  1718607773
# 9              8.07      WF  1718607775

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Filter the Southern Hemisphere data (Lat < 0)
southern_hemisphere_df = city_data_df[city_data_df['Latitude'] < 0]

# Extract Latitude and Max Temperature for the Southern Hemisphere
latitude = southern_hemisphere_df['Latitude']
max_temp = southern_hemisphere_df['Temperature']

# Calculate linear regression
slope, intercept, r_value, p_value, std_err = linregress(latitude, max_temp)

# Create regression line values
regress_values = latitude * slope + intercept

# Plot scatter plot and regression line
plt.figure(figsize=(10, 8))

# Lat vs. Max Temperature
plt.scatter(latitude, max_temp, c='green', edgecolors='w', linewidth=0.5, label='5, 0.5 0.1')
plt.plot(latitude, regress_values, 'r-', label=f'Fit line (R²={r_value**2:.2f})')
plt.title('Latitude vs. Max Temp')
plt.xlabel('Latitude')
plt.ylabel('Temperature (°C)')
plt.legend()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
temprature_df = city_data_df[city_data_df['Latitude'] >= 0]
temprature_df
# Out:
#          Latitude  Temperature  Humidity  Cloudiness  Wind Speed
# City_ID
# 0         41.6911        25.98        50           0        4.12
# 2         21.9789        27.24        71          40        8.75
# 3         64.8569        17.14        79          75        1.54
# 5         52.3333        17.90        61          88        0.85
# 7         54.8680         9.62        93          40        0.00
# ...           ...          ...       ...         ...         ...
# 591       38.1702         6.87        50         100        0.61
# 592        2.7858        21.35        99          98        0.74
# 593       49.4212        17.53        69          49        0.16
# 594       28.3667        27.91        83          98        7.20
# 596        3.2607        27.98        82          67        1.89
#
# [420 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Filter the Southern Hemisphere data (Lat < 0)
southern_hemisphere_df = city_data_df[city_data_df['Latitude'] < 0]

# Extract Latitude and Max Temperature for the Southern Hemisphere
latitude = southern_hemisphere_df['Latitude']
max_temp = southern_hemisphere_df['Temperature']

# Calculate linear regression
slope, intercept, r_value, p_value, std_err = linregress(latitude, max_temp)

# Create regression line values
regress_values = latitude * slope + intercept

# Plot scatter plot and regression line
plt.figure(figsize=(10, 8))

# Lat vs. Max Temperature
plt.scatter(latitude, max_temp, c='green', edgecolors='w', linewidth=0.5, label='5, 0.5 0.1')
plt.plot(latitude, regress_values, 'r-', label=f'Fit line (R²={r_value**2:.2f})')
plt.title('Latitude vs. Max Temp')
plt.xlabel('Latitude')
plt.ylabel('Temperature (°C)')
plt.legend()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.6720220238897325

# %% [markdown]
# ***Discussion about the linear relationship:*** Latitude vs Max Temperature
#
# The relationship between latitude and maximum temperature (referred to as "Temperature") in both the Northern and Southern Hemispheres explored using linear regression analysis, presented in the scatter plots with corresponding regression lines provide insights into how temperature varies with latitude across these regions. In both Hemispheres, the scatter plots of latitude versus temperature reveal noticeable patterns of temperature variation across different latitudes. The linear regression analysis yield specific sloped and interceptd, along with R² value, indicating a moderate correlations between latitude and temperature. The slopes of the regression lines suggest that as we move away from the equator (towards higher latitudes), the temperature tends to decrease.
#
# Comparative Analysis
# When comparing the two hemispheres, both exhibit a moderate negative correlation between latitude and temperature. The scatter plots and linear regression lines highlight that temperature tends to decrease with increasing latitude in both the Northern and Southern Hemispheres. This is consistent with the understanding that regions closer to the equator receive more direct sunlight and are generally warmer, while regions further from the equator receive less direct sunlight and are cooler.
#
# The R² values (R² = 0.64) in both hemispheres indicate that latitude is a significant predictor of temperature, explaining a moderate proportion of the variance in temperature. This similarity suggests that the fundamental relationship between latitude and temperature is consistent across both hemispheres, despite the presence of other influencing factors. However, the specific slopes and intercepts of the regression lines may differ between the hemispheres, reflecting regional climatic differences, geographical features, and other environmental factors unique to each hemisphere. These differences highlight the complexity of temperature distribution and the importance of considering a range of factors when analyzing temperature patterns.
#
# Conclusion
# In conclusion, the linear regression analysis of latitude versus maximum temperature in both the Northern and Southern Hemispheres demonstrates a moderate negative correlation. Latitude is a significant determinant of temperature in both hemispheres, with temperature decreasing as latitude increases. The findings highlight the importance of latitude in shaping temperature patterns, while also recognizing the influence of other climatic and geographical factors. A comprehensive analysis that considers these additional factors is necessary to fully understand temperature distribution across different regions.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.007659599322853922

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Read the city data from the CSV file
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Create a DataFrame with the Southern Hemisphere data (Latitude >= 0)
southern_hemisphere_df = city_data_df[city_data_df['Latitude'] >= 0]

# Extract Latitude and Humidity for the Southern Hemisphere
latitude = southern_hemisphere_df['Latitude']
humidity = southern_hemisphere_df['Humidity']

# Calculate linear regression
slope, intercept, r_value, p_value, std_err = linregress(latitude, humidity)

# Create regression line values
regress_values = latitude * slope + intercept

# Plot scatter plot and regression line
plt.figure(figsize=(8, 6))

# Humidity vs. Latitude
plt.scatter(latitude, humidity, c='green', edgecolors='w', linewidth=0.5, label='-50, -40, -30... 0')
plt.plot(latitude, regress_values, 'r-', label=f'Fit line (R²={r_value**2:.2f})')
plt.title('Humidity vs Latitude (Southern Hemisphere)')
plt.xlabel('Latitude')
plt.ylabel('Humidity')

plt.legend()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.00014367159540169783

# %% [markdown]
# ***Discussion about the linear relationship*** Latitude vs Humidity
#
# Overview
# The relationship between latitude and humidity in both the Northern and Southern Hemispheres as explored in this linear regression analysis through the scatter plots and corresponding regression lines provide insights into how humidity varies with latitude across these regions. The dispersion of data points implie that other factors, such as local climatic conditions, geographic features, and regional weather patterns, significantly influence humidity levels. These factors can vary widely and contribute to the weak correlation observed across the two hemispheres.
#
# Comparative Analysis
# When comparing the two hemispheres, it is evident that both exhibit a weak correlation between latitude and humidity. The scatter plots and linear regression lines highlight that latitude is not a significant determinant of humidity in either hemisphere. The R² values (R² = 0.00) in both cases are low, indicating that the proportion of variance in humidity explained by latitude is minimal.
#
# Both hemispheres share similarities in terms of the factors influencing humidity levels. These include local climate variations, geographical influences, and weather patterns, all of which can vary independently of latitude. The weak correlation observed in both hemispheres underscores the complexity of humidity distribution and the need to consider a broader range of factors when analyzing humidity patterns.
#
# Conclusion
# In conclusion, the linear regression analysis of latitude versus humidity in both the Northern and Southern Hemispheres demonstrates a weak correlation. The low R² values indicate that latitude is not a strong predictor of humidity levels, highlighting the importance of considering other factors that influence humidity. The findings suggest that while latitude provides a general framework for climatic zones, it is insufficient for accurately predicting humidity. A more comprehensive analysis that accounts for various local and regional factors is necessary to understand humidity distribution more accurately.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Read the city data from the CSV file
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")


# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemisphere_df = city_data_df[city_data_df['Latitude'] >= 0]

# Extract Latitude and Cloudiness for the Northern Hemisphere
latitude = northern_hemisphere_df['Latitude']
cloudiness = northern_hemisphere_df['Cloudiness']

# Calculate linear regression
slope, intercept, r_value, p_value, std_err = linregress(latitude, cloudiness)

# Create regression line values
regress_values = latitude * slope + intercept

# Plot scatter plot and regression line
plt.figure(figsize=(8, 6))

# Humidity vs. Latitude
plt.scatter(latitude, cloudiness, c='green', edgecolors='w', linewidth=0.5, label='')
plt.plot(latitude, regress_values, 'r-', label=f'Fit line (R²={r_value**2:.2f})')
plt.title('Latitude vs Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

plt.legend()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.006456908379763574

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Read the city data from the CSV file
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Create a DataFrame with the Southern Hemisphere data (Latitude >= 0)
southern_hemisphere_df = city_data_df[city_data_df['Latitude'] >= 0]

# Extract Latitude and Humidity for the Southern Hemisphere
latitude = southern_hemisphere_df['Latitude']
cloudiness = southern_hemisphere_df['Cloudiness']

# Calculate linear regression
slope, intercept, r_value, p_value, std_err = linregress(latitude, cloudiness)

# Create regression line values
regress_values = latitude * slope + intercept

# Plot scatter plot and regression line
plt.figure(figsize=(8, 6))

# Humidity vs. Latitude
plt.scatter(latitude, cloudiness, c='green', edgecolors='w', linewidth=0.5, label='-50, -40...0')
plt.plot(latitude, regress_values, 'r-', label=f'Fit line (R²={r_value**2:.2f})')
plt.title('Latitude vs. Cloudiness (Southern Hemisphere)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

plt.legend()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.018616831531634456

# %% [markdown]
# **Discussion about the linear relationship:** Latitude vs Cloudiness
#
# Overview
#  By examining the scatter plots and regression lines, we can draw insights into how cloudiness varies with latitude across these regions. In both Northern and Southern Hemispheres, the scatter plots of latitude versus cloudiness show dispersed range of cloudiness values across different latitudes. The linear regression lines, indicates a weak correlation between latitude and cloudiness. The R² values of (R²=0.01) in both cases, measure the proportions of the variances in cloudiness that can be explained by latitude, is relatively low , suggesting that latitude is not a strong predictor of cloudiness in both cases.
#
# Comparative Analysis
# When comparing the two hemispheres, it is evident that the relationship between latitude and cloudiness is weak in both cases. The scatter plots and linear regression lines reveal that latitude is not a strong determinant of cloudiness levels in either hemisphere. This finding underscores the importance of considering a wider range of factors when analyzing cloudiness patterns, including geographical, meteorological, and environmental influences.
#
# Conclusion
# In conclusion, the linear regression analysis of latitude versus cloudiness in both the Northern and Southern Hemispheres demonstrates a weak correlation. The low R² values indicate that latitude is not a significant predictor of cloudiness, pointing to the need for a broader consideration of factors influencing cloudiness levels. This analysis highlights the complexity of climatic variables and the limitations of using latitude as a sole predictor for cloudiness. Understanding the interplay of various factors is essential for a more accurate and comprehensive analysis of cloudiness distribution across the globe.

# %% [markdown]
# ### Latitude vs. Wind Speed Linear Regression Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Read the city data from the CSV file
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")


# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemisphere_df = city_data_df[city_data_df['Latitude'] >= 0]

# Extract Latitude and Wind Speed for the Northern Hemisphere
latitude = northern_hemisphere_df['Latitude']
wind_speed = northern_hemisphere_df['Wind Speed']

# Calculate linear regression
slope, intercept, r_value, p_value, std_err = linregress(latitude, wind_speed)

# Create regression line values
regress_values = latitude * slope + intercept

# Plot scatter plot and regression line
plt.figure(figsize=(8, 6))

# Humidity vs. Latitude
plt.scatter(latitude, wind_speed, c='green', edgecolors='w', linewidth=0.5, label='')
plt.plot(latitude, regress_values, 'r-', label=f'Fit line (R²={r_value**2:.2f})')
plt.title('Latitude vs Wind Speed (Northern Hemisphere)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

plt.legend()

# Save the figure
plt.savefig("output_data/Fig5.png")

# Show plot
plt.show()

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.0017236249523139959

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Read the city data from the CSV file
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")


# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
southern_hemisphere_df = city_data_df[city_data_df['Latitude'] >= 0]

# Extract Latitude and Wind Speed for the Northern Hemisphere
latitude = southern_hemisphere_df['Latitude']
wind_speed = southern_hemisphere_df['Wind Speed']

# Calculate linear regression
slope, intercept, r_value, p_value, std_err = linregress(latitude, wind_speed)

# Create regression line values
regress_values = latitude * slope + intercept

# Plot scatter plot and regression line
plt.figure(figsize=(8, 6))

# Humidity vs. Latitude
plt.scatter(latitude, wind_speed, c='green', edgecolors='w', linewidth=0.5, label='')
plt.plot(latitude, regress_values, 'r-', label=f'Fit line (R²={r_value**2:.2f})')
plt.title('Latitude vs Wind Speed (Southern Hemisphere)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

plt.legend()

# Save the figure
plt.savefig("output_data/Fig6.png")

# Show plot
plt.show()

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r^2-value is: 0.06495869418886388

# %% [markdown]
# ***Discussion about the linear relationship:*** Latitude versus Wind Speed
#
# Correlation: Both plots presenting linear regression of Latitude versus Wind Speed in Northern and Southern hemispheres demonstrate a weak correlation between latitude and wind speed, as indicated by the low R² values (0.02). This suggests that latitude alone is not a strong predictor of wind speed.
#
# Trend: The negative slopes in both plots suggest a slight tendency for wind speeds to decrease as latitude increases. However, the low R² values suggest that this trend is not strong and that other factors may play more significant roles in determining wind speeds.
#
# Data Distribution: The scatter of data points in both plots show significant variability, suggesting that wind speed is influenced by multiple factors beyond latitude, such as geographic features, weather patterns, and local conditions. These visualizations indicate that while there is a slight negative correlation between latitude and wind speed in both hemispheres, the relationship is weak. Further analysis with additional variables and more sophisticated models would be necessary to understand the factors influencing wind speed more comprehensively.
